# %%
inventario =  [ {'nombre': 'Camisa', 'precio': 20, 'cantidad': 40},
               {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 30},
               {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25},
               {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 15},
               {'nombre': 'Falda', 'precio': 25, 'cantidad': 20},
               {'nombre': 'Gorra', 'precio': 10, 'cantidad': 50},
               {'nombre': 'Bufanda', 'precio': 15, 'cantidad': 35},
               {'nombre': 'Calcetines', 'precio': 5, 'cantidad': 100},
               {'nombre': 'Cinturón', 'precio': 12, 'cantidad': 40},
               {'nombre': 'Bolso', 'precio': 45, 'cantidad': 18}]

# %%
for producto in inventario:
    print(f"el producto {producto ["nombre"]} vale {producto ["precio"]} y hay {producto ["cantidad"]}")
# Out:
# el producto Camisa vale 20 y hay 40
# el producto Pantalón vale 30 y hay 30
# el producto Zapatos vale 50 y hay 25
# el producto Chaqueta vale 70 y hay 15
# el producto Falda vale 25 y hay 20
# el producto Gorra vale 10 y hay 50
# el producto Bufanda vale 15 y hay 35
# el producto Calcetines vale 5 y hay 100
# el producto Cinturón vale 12 y hay 40
# el producto Bolso vale 45 y hay 18

# %%
# 1. Agregar producto al inventario o actualiza su cantidad si ya existe
#    Debe recibir el nombre, precio y cantidad del producto como parámetros.
def agregar_producto(nombre, precio, cantidad): 
    for producto in inventario:
        if producto ["nombre"] == nombre:
            producto ["cantidad"] = producto["cantidad"]+cantidad   
            return
    inventario.append({"nombre": nombre, 
                        "precio": precio, 
                        "cantidad": cantidad})

# %%
# 1. agregar primer producto
agregar_producto("corbata", 20, 30)
print(inventario)
# Out:
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 40}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 30}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 15}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}, {'nombre': 'Gorra', 'precio': 10, 'cantidad': 50}, {'nombre': 'Bufanda', 'precio': 15, 'cantidad': 35}, {'nombre': 'Calcetines', 'precio': 5, 'cantidad': 100}, {'nombre': 'Cinturón', 'precio': 12, 'cantidad': 40}, {'nombre': 'Bolso', 'precio': 45, 'cantidad': 18}, {'nombre': 'corbata', 'precio': 20, 'cantidad': 30}]

# %%
# 1. agregar producto repetido

agregar_producto("corbata", 20, 5)
print(inventario)
# Out:
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 40}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 30}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 15}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}, {'nombre': 'Gorra', 'precio': 10, 'cantidad': 50}, {'nombre': 'Bufanda', 'precio': 15, 'cantidad': 35}, {'nombre': 'Calcetines', 'precio': 5, 'cantidad': 100}, {'nombre': 'Cinturón', 'precio': 12, 'cantidad': 40}, {'nombre': 'Bolso', 'precio': 45, 'cantidad': 18}, {'nombre': 'corbata', 'precio': 20, 'cantidad': 35}]

# %%
# 1. agregar producto diferente

agregar_producto("pantalon", 20, 30)
print(inventario)
# Out:
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 40}, {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 30}, {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25}, {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 15}, {'nombre': 'Falda', 'precio': 25, 'cantidad': 20}, {'nombre': 'Gorra', 'precio': 10, 'cantidad': 50}, {'nombre': 'Bufanda', 'precio': 15, 'cantidad': 35}, {'nombre': 'Calcetines', 'precio': 5, 'cantidad': 100}, {'nombre': 'Cinturón', 'precio': 12, 'cantidad': 40}, {'nombre': 'Bolso', 'precio': 45, 'cantidad': 18}, {'nombre': 'corbata', 'precio': 20, 'cantidad': 35}, {'nombre': 'pantalon', 'precio': 20, 'cantidad': 30}]

# %%
# 2. Ver inventario

def ver_inventario(inventario):
    for producto in inventario:
        print("Nombre:",producto["nombre"],", Precio:$",producto["precio"],", Cantidad",producto["cantidad"])
    return

# %%
#2. Ver inventario

ver_inventario(inventario)
# Out:
# Nombre: Camisa , Precio:$ 20 , Cantidad 40
# Nombre: Pantalón , Precio:$ 30 , Cantidad 30
# Nombre: Zapatos , Precio:$ 50 , Cantidad 25
# Nombre: Chaqueta , Precio:$ 70 , Cantidad 15
# Nombre: Falda , Precio:$ 25 , Cantidad 20
# Nombre: Gorra , Precio:$ 10 , Cantidad 50
# Nombre: Bufanda , Precio:$ 15 , Cantidad 35
# Nombre: Calcetines , Precio:$ 5 , Cantidad 100
# Nombre: Cinturón , Precio:$ 12 , Cantidad 40
# Nombre: Bolso , Precio:$ 45 , Cantidad 18
# Nombre: corbata , Precio:$ 20 , Cantidad 35
# Nombre: pantalon , Precio:$ 20 , Cantidad 30

# %%
# 3. Buscar producto por nombre

def buscar_producto(nombre):
    for producto in inventario:
        if producto ["nombre"] == nombre:
            print(producto)           
            return
    print("Producto no encontrado")

# %%
# 3. comprobar

buscar_producto("camisa")
# Out:
# Producto no encontrado

# %%
# 4. Actualizar el stock de un producto en el inventario. 
# Debe recibir el nombre del producto y la cantidad a agregar o quitar como parámetros.

def actualizar_stock(nombre, cantidad):
    for producto in inventario:
        if producto["nombre"] == nombre:
            producto.update({"cantidad":cantidad})
            return    
    print("no hay suficiente stock")

# %%
actualizar_stock("camisa", 30)
# Out:
# no hay suficiente stock

# %%
inventario
# Out:
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 40},
#  {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 30},
#  {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25},
#  {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 15},
#  {'nombre': 'Falda', 'precio': 25, 'cantidad': 20},
#  {'nombre': 'Gorra', 'precio': 10, 'cantidad': 50},
#  {'nombre': 'Bufanda', 'precio': 15, 'cantidad': 35},
#  {'nombre': 'Calcetines', 'precio': 5, 'cantidad': 100},
#  {'nombre': 'Cinturón', 'precio': 12, 'cantidad': 40},
#  {'nombre': 'Bolso', 'precio': 45, 'cantidad': 18},
#  {'nombre': 'corbata', 'precio': 20, 'cantidad': 35},
#  {'nombre': 'pantalon', 'precio': 20, 'cantidad': 30}]

# %%
# 5. Eliminar un producto (nombre) 

def eliminar_producto_nombre(nombre):
    for producto in inventario:
        if producto["nombre"] == nombre.lower():
           inventario.remove(producto)
           return
    print("El producto no está en el inventaro")

# %%
# 5. Eliminar un producto (nombre) 

eliminar_producto_nombre("corbata")
inventario
# Out:
# [{'nombre': 'Camisa', 'precio': 20, 'cantidad': 40},
#  {'nombre': 'Pantalón', 'precio': 30, 'cantidad': 30},
#  {'nombre': 'Zapatos', 'precio': 50, 'cantidad': 25},
#  {'nombre': 'Chaqueta', 'precio': 70, 'cantidad': 15},
#  {'nombre': 'Falda', 'precio': 25, 'cantidad': 20},
#  {'nombre': 'Gorra', 'precio': 10, 'cantidad': 50},
#  {'nombre': 'Bufanda', 'precio': 15, 'cantidad': 35},
#  {'nombre': 'Calcetines', 'precio': 5, 'cantidad': 100},
#  {'nombre': 'Cinturón', 'precio': 12, 'cantidad': 40},
#  {'nombre': 'Bolso', 'precio': 45, 'cantidad': 18},
#  {'nombre': 'pantalon', 'precio': 20, 'cantidad': 30}]

# %%
# 6. Calcular valor del inventario 


def calcular_valor_inventario(inventario):
    valor_total = 0
    for valor in inventario:
        valor_nombre = valor["precio"]*valor["cantidad"]
        valor_total = valor_total + valor_nombre   
    print(valor_total)

# %%
calcular_valor_inventario(inventario)
# Out:
# 7915

# %%
#7. realizar compra
# mostrar inventario al cliente: productos, precios y cantidades
# preguntar qué quiere comprar: el cliente escribe nombre del producto
# comprobar si existe. Ese producto está en el inventario?
# pedir cantidad. Preguntar al cliente cuántos quiere comprar
# añadir al carrito: se guarda lo que se ha comprado
# actualizar el inventario
# preguntar si quiere seguir comprando
# calcular total
# mostrar resultado final
#while: seguir comprando hasta que el cliente diga parar


def realizar_compra():
    carrito = []
    total = 0
    seguir_comprando = True

    while seguir_comprando:
        ver_inventario() 
        compra = input("que producto quieres comprar").strip().capitalize()   
        for producto in inventario:
            if producto["nombre"] == compra:
                cantidad = int(input("¿Cuántos quiere?"))
                
                if producto ["cantidad"] < cantidad:
                    print ("No hay suficiente stock")
                else:
                    carrito.append({"nombre": producto["nombre"],
                                    "cantidad": cantidad,
                                    "precio": producto["precio"]})
                    producto["cantidad"] = producto["cantidad"] - cantidad
                    total = total + producto ["precio"] * cantidad    
                break
        else:
            print("no tenemos ese producto")
            break
        respuesta = input("Quieres seguir comprando? si/no").lower().strip()
        
        if respuesta == "no":
            seguir_comprando == False  
    print("total de la compra:", total)          



    ## Yanelis, no puedo más :'(

# %%
realizar_compra()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 realizar_compra()
#
# Cell In[12], line 20, in realizar_compra()
#      17 seguir_comprando = True
#      19 while seguir_comprando:
# ---> 20     ver_inventario()
#      21     compra = input("que producto quieres comprar").strip().capitalize()
#      22     for producto in inventario:
#
# TypeError: ver_inventario() missing 1 required positional argument: 'inventario'

# %%
pregunta = input("quieres seguir comprando?")  #preguntar si quiere seguir comprando
            if pregunta = "no"
    
    seguir_comprando = False
